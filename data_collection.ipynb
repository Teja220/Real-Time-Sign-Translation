# %%
# ---------------------------------------------
# SCRIPT: data_collection.ipynb
# PURPOSE: Collect sequences of keypoints for sign language gestures
# ---------------------------------------------

# STEP 1: Import Required Libraries
import os
import numpy as np
import cv2
import mediapipe as mp
import time

# STEP 2: Define Actions (Signs)
actions = [
    'hello', 'iloveyou', 'please', 'thankyou', 'ok',
    'excuseme', 'sorry', 'welcome', 'stop', 'goodbye'
]

# STEP 3: Setup Parameters
DATA_PATH = os.path.join('MP_Data')
sequence_length = 30
sequences_per_action = 30  # Collect 30 sequences at once
RESET_SEQUENCES = True

# STEP 4: Extract Keypoints Function
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# STEP 5: Start Data Collection
mp_holistic = mp.solutions.holistic
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    for action in actions:
        start_sequence = 0 if RESET_SEQUENCES else len(os.listdir(os.path.join(DATA_PATH, action))) if os.path.exists(os.path.join(DATA_PATH, action)) else 0
        print(f"\nStarting data collection for '{action.upper()}' in 5 seconds...")
        time.sleep(5)
        for sequence in range(start_sequence, start_sequence + sequences_per_action):
            print(f"  Sequence {sequence} for action '{action}'")
            for frame_num in range(sequence_length):
                ret, frame = cap.read()
                image, results = frame.copy(), holistic.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))

                cv2.putText(frame, f'{action.upper()} - Seq {sequence} Frame {frame_num}', (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0,255,0), 2, cv2.LINE_AA)
                cv2.imshow('OpenCV Feed', frame)

                keypoints = extract_keypoints(results)
                npy_path = os.path.join(DATA_PATH, action, str(sequence))
                os.makedirs(npy_path, exist_ok=True)
                np.save(os.path.join(npy_path, str(frame_num)), keypoints)

                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

cap.release()
cv2.destroyAllWindows()
# Out:
# Starting data collection for 'HELLO' in 5 seconds...
#   Sequence 0 for action 'hello'
#   Sequence 1 for action 'hello'
#   Sequence 2 for action 'hello'
#   Sequence 3 for action 'hello'
#   Sequence 4 for action 'hello'
#   Sequence 5 for action 'hello'
#   Sequence 6 for action 'hello'
#   Sequence 7 for action 'hello'
#   Sequence 8 for action 'hello'
#   Sequence 9 for action 'hello'
#   Sequence 10 for action 'hello'
#   Sequence 11 for action 'hello'
#   Sequence 12 for action 'hello'
#   Sequence 13 for action 'hello'
#   Sequence 14 for action 'hello'
#   Sequence 15 for action 'hello'
#   Sequence 16 for action 'hello'
#   Sequence 17 for action 'hello'
#   Sequence 18 for action 'hello'
#   Sequence 19 for action 'hello'
#   Sequence 20 for action 'hello'
#   Sequence 21 for action 'hello'
#   Sequence 22 for action 'hello'
#   Sequence 23 for action 'hello'
#   Sequence 24 for action 'hello'
#   Sequence 25 for action 'hello'
#   Sequence 26 for action 'hello'
#   Sequence 27 for action 'hello'
#   Sequence 28 for action 'hello'
#   Sequence 29 for action 'hello'
#
# Starting data collection for 'ILOVEYOU' in 5 seconds...
#   Sequence 0 for action 'iloveyou'
#   Sequence 1 for action 'iloveyou'
#   Sequence 2 for action 'iloveyou'
#   Sequence 3 for action 'iloveyou'
#   Sequence 4 for action 'iloveyou'
#   Sequence 5 for action 'iloveyou'
#   Sequence 6 for action 'iloveyou'
#   Sequence 7 for action 'iloveyou'
#   Sequence 8 for action 'iloveyou'
#   Sequence 9 for action 'iloveyou'
#   Sequence 10 for action 'iloveyou'
#   Sequence 11 for action 'iloveyou'
#   Sequence 12 for action 'iloveyou'
#   Sequence 13 for action 'iloveyou'
#   Sequence 14 for action 'iloveyou'
#   Sequence 15 for action 'iloveyou'
#   Sequence 16 for action 'iloveyou'
#   Sequence 17 for action 'iloveyou'
#   Sequence 18 for action 'iloveyou'
#   Sequence 19 for action 'iloveyou'
#   Sequence 20 for action 'iloveyou'
#   Sequence 21 for action 'iloveyou'
#   Sequence 22 for action 'iloveyou'
#   Sequence 23 for action 'iloveyou'
#   Sequence 24 for action 'iloveyou'
#   Sequence 25 for action 'iloveyou'
#   Sequence 26 for action 'iloveyou'
#   Sequence 27 for action 'iloveyou'
#   Sequence 28 for action 'iloveyou'
#   Sequence 29 for action 'iloveyou'
#
# Starting data collection for 'PLEASE' in 5 seconds...
#   Sequence 0 for action 'please'
#   Sequence 1 for action 'please'
#   Sequence 2 for action 'please'
#   Sequence 3 for action 'please'
#   Sequence 4 for action 'please'
#   Sequence 5 for action 'please'
#   Sequence 6 for action 'please'
#   Sequence 7 for action 'please'
#   Sequence 8 for action 'please'
#   Sequence 9 for action 'please'
#   Sequence 10 for action 'please'
#   Sequence 11 for action 'please'
#   Sequence 12 for action 'please'
#   Sequence 13 for action 'please'
#   Sequence 14 for action 'please'
#   Sequence 15 for action 'please'
#   Sequence 16 for action 'please'
#   Sequence 17 for action 'please'
#   Sequence 18 for action 'please'
#   Sequence 19 for action 'please'
#   Sequence 20 for action 'please'
#   Sequence 21 for action 'please'
#   Sequence 22 for action 'please'
#   Sequence 23 for action 'please'
#   Sequence 24 for action 'please'
#   Sequence 25 for action 'please'
#   Sequence 26 for action 'please'
#   Sequence 27 for action 'please'
#   Sequence 28 for action 'please'
#   Sequence 29 for action 'please'
#
# Starting data collection for 'THANKYOU' in 5 seconds...
#   Sequence 0 for action 'thankyou'
#   Sequence 1 for action 'thankyou'
#   Sequence 2 for action 'thankyou'
#   Sequence 3 for action 'thankyou'
#   Sequence 4 for action 'thankyou'
#   Sequence 5 for action 'thankyou'
#   Sequence 6 for action 'thankyou'
#   Sequence 7 for action 'thankyou'
#   Sequence 8 for action 'thankyou'
#   Sequence 9 for action 'thankyou'
#   Sequence 10 for action 'thankyou'
#   Sequence 11 for action 'thankyou'
#   Sequence 12 for action 'thankyou'
#   Sequence 13 for action 'thankyou'
#   Sequence 14 for action 'thankyou'
#   Sequence 15 for action 'thankyou'
#   Sequence 16 for action 'thankyou'
#   Sequence 17 for action 'thankyou'
#   Sequence 18 for action 'thankyou'
#   Sequence 19 for action 'thankyou'
#   Sequence 20 for action 'thankyou'
#   Sequence 21 for action 'thankyou'
#   Sequence 22 for action 'thankyou'
#   Sequence 23 for action 'thankyou'
#   Sequence 24 for action 'thankyou'
#   Sequence 25 for action 'thankyou'
#   Sequence 26 for action 'thankyou'
#   Sequence 27 for action 'thankyou'
#   Sequence 28 for action 'thankyou'
#   Sequence 29 for action 'thankyou'
#
# Starting data collection for 'OK' in 5 seconds...
#   Sequence 0 for action 'ok'
#   Sequence 1 for action 'ok'
#   Sequence 2 for action 'ok'
#   Sequence 3 for action 'ok'
#   Sequence 4 for action 'ok'
#   Sequence 5 for action 'ok'
#   Sequence 6 for action 'ok'
#   Sequence 7 for action 'ok'
#   Sequence 8 for action 'ok'
#   Sequence 9 for action 'ok'
#   Sequence 10 for action 'ok'
#   Sequence 11 for action 'ok'
#   Sequence 12 for action 'ok'
#   Sequence 13 for action 'ok'
#   Sequence 14 for action 'ok'
#   Sequence 15 for action 'ok'
#   Sequence 16 for action 'ok'
#   Sequence 17 for action 'ok'
#   Sequence 18 for action 'ok'
#   Sequence 19 for action 'ok'
#   Sequence 20 for action 'ok'
#   Sequence 21 for action 'ok'
#   Sequence 22 for action 'ok'
#   Sequence 23 for action 'ok'
#   Sequence 24 for action 'ok'
#   Sequence 25 for action 'ok'
#   Sequence 26 for action 'ok'
#   Sequence 27 for action 'ok'
#   Sequence 28 for action 'ok'
#   Sequence 29 for action 'ok'
#
# Starting data collection for 'EXCUSEME' in 5 seconds...
#   Sequence 0 for action 'excuseme'
#   Sequence 1 for action 'excuseme'
#   Sequence 2 for action 'excuseme'
#   Sequence 3 for action 'excuseme'
#   Sequence 4 for action 'excuseme'
#   Sequence 5 for action 'excuseme'
#   Sequence 6 for action 'excuseme'
#   Sequence 7 for action 'excuseme'
#   Sequence 8 for action 'excuseme'
#   Sequence 9 for action 'excuseme'
#   Sequence 10 for action 'excuseme'
#   Sequence 11 for action 'excuseme'
#   Sequence 12 for action 'excuseme'
#   Sequence 13 for action 'excuseme'
#   Sequence 14 for action 'excuseme'
#   Sequence 15 for action 'excuseme'
#   Sequence 16 for action 'excuseme'
#   Sequence 17 for action 'excuseme'
#   Sequence 18 for action 'excuseme'
#   Sequence 19 for action 'excuseme'
#   Sequence 20 for action 'excuseme'
#   Sequence 21 for action 'excuseme'
#   Sequence 22 for action 'excuseme'
#   Sequence 23 for action 'excuseme'
#   Sequence 24 for action 'excuseme'
#   Sequence 25 for action 'excuseme'
#   Sequence 26 for action 'excuseme'
#   Sequence 27 for action 'excuseme'
#   Sequence 28 for action 'excuseme'
#   Sequence 29 for action 'excuseme'
#
# Starting data collection for 'SORRY' in 5 seconds...
#   Sequence 0 for action 'sorry'
#   Sequence 1 for action 'sorry'
#   Sequence 2 for action 'sorry'
#   Sequence 3 for action 'sorry'
#   Sequence 4 for action 'sorry'
#   Sequence 5 for action 'sorry'
#   Sequence 6 for action 'sorry'
#   Sequence 7 for action 'sorry'
#   Sequence 8 for action 'sorry'
#   Sequence 9 for action 'sorry'
#   Sequence 10 for action 'sorry'
#   Sequence 11 for action 'sorry'
#   Sequence 12 for action 'sorry'
#   Sequence 13 for action 'sorry'
#   Sequence 14 for action 'sorry'
#   Sequence 15 for action 'sorry'
#   Sequence 16 for action 'sorry'
#   Sequence 17 for action 'sorry'
#   Sequence 18 for action 'sorry'
#   Sequence 19 for action 'sorry'
#   Sequence 20 for action 'sorry'
#   Sequence 21 for action 'sorry'
#   Sequence 22 for action 'sorry'
#   Sequence 23 for action 'sorry'
#   Sequence 24 for action 'sorry'
#   Sequence 25 for action 'sorry'
#   Sequence 26 for action 'sorry'
#   Sequence 27 for action 'sorry'
#   Sequence 28 for action 'sorry'
#   Sequence 29 for action 'sorry'
#
# Starting data collection for 'WELCOME' in 5 seconds...
#   Sequence 0 for action 'welcome'
#   Sequence 1 for action 'welcome'
#   Sequence 2 for action 'welcome'
#   Sequence 3 for action 'welcome'
#   Sequence 4 for action 'welcome'
#   Sequence 5 for action 'welcome'
#   Sequence 6 for action 'welcome'
#   Sequence 7 for action 'welcome'
#   Sequence 8 for action 'welcome'
#   Sequence 9 for action 'welcome'
#   Sequence 10 for action 'welcome'
#   Sequence 11 for action 'welcome'
#   Sequence 12 for action 'welcome'
#   Sequence 13 for action 'welcome'
#   Sequence 14 for action 'welcome'
#   Sequence 15 for action 'welcome'
#   Sequence 16 for action 'welcome'
#   Sequence 17 for action 'welcome'
#   Sequence 18 for action 'welcome'
#   Sequence 19 for action 'welcome'
#   Sequence 20 for action 'welcome'
#   Sequence 21 for action 'welcome'
#   Sequence 22 for action 'welcome'
#   Sequence 23 for action 'welcome'
#   Sequence 24 for action 'welcome'
#   Sequence 25 for action 'welcome'
#   Sequence 26 for action 'welcome'
#   Sequence 27 for action 'welcome'
#   Sequence 28 for action 'welcome'
#   Sequence 29 for action 'welcome'
#
# Starting data collection for 'STOP' in 5 seconds...
#   Sequence 0 for action 'stop'
#   Sequence 1 for action 'stop'
#   Sequence 2 for action 'stop'
#   Sequence 3 for action 'stop'
#   Sequence 4 for action 'stop'
#   Sequence 5 for action 'stop'
#   Sequence 6 for action 'stop'
#   Sequence 7 for action 'stop'
#   Sequence 8 for action 'stop'
#   Sequence 9 for action 'stop'
#   Sequence 10 for action 'stop'
#   Sequence 11 for action 'stop'
#   Sequence 12 for action 'stop'
#   Sequence 13 for action 'stop'
#   Sequence 14 for action 'stop'
#   Sequence 15 for action 'stop'
#   Sequence 16 for action 'stop'
#   Sequence 17 for action 'stop'
#   Sequence 18 for action 'stop'
#   Sequence 19 for action 'stop'
#   Sequence 20 for action 'stop'
#   Sequence 21 for action 'stop'
#   Sequence 22 for action 'stop'
#   Sequence 23 for action 'stop'
#   Sequence 24 for action 'stop'
#   Sequence 25 for action 'stop'
#   Sequence 26 for action 'stop'
#   Sequence 27 for action 'stop'
#   Sequence 28 for action 'stop'
#   Sequence 29 for action 'stop'
#
# Starting data collection for 'GOODBYE' in 5 seconds...
#   Sequence 0 for action 'goodbye'
#   Sequence 1 for action 'goodbye'
#   Sequence 2 for action 'goodbye'
#   Sequence 3 for action 'goodbye'
#   Sequence 4 for action 'goodbye'
#   Sequence 5 for action 'goodbye'
#   Sequence 6 for action 'goodbye'
#   Sequence 7 for action 'goodbye'
#   Sequence 8 for action 'goodbye'
#   Sequence 9 for action 'goodbye'
#   Sequence 10 for action 'goodbye'
#   Sequence 11 for action 'goodbye'
#   Sequence 12 for action 'goodbye'
#   Sequence 13 for action 'goodbye'
#   Sequence 14 for action 'goodbye'
#   Sequence 15 for action 'goodbye'
#   Sequence 16 for action 'goodbye'
#   Sequence 17 for action 'goodbye'
#   Sequence 18 for action 'goodbye'
#   Sequence 19 for action 'goodbye'
#   Sequence 20 for action 'goodbye'
#   Sequence 21 for action 'goodbye'
#   Sequence 22 for action 'goodbye'
#   Sequence 23 for action 'goodbye'
#   Sequence 24 for action 'goodbye'
#   Sequence 25 for action 'goodbye'
#   Sequence 26 for action 'goodbye'
#   Sequence 27 for action 'goodbye'
#   Sequence 28 for action 'goodbye'
#   Sequence 29 for action 'goodbye'
